# %% [markdown]
# <a href="https://colab.research.google.com/github/TonyChennn/-titanic-analysis-/blob/main/%E9%90%B5%E9%81%94%E5%B0%BC%E8%99%9F%E5%AD%98%E6%B4%BB%E5%B0%88%E6%A1%88.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Enviroment

# %%
import pandas as pd
import numpy as np

# %%
url = 'https://raw.githubusercontent.com/dsindy/kaggle-titanic/master/data/train.csv'
df = pd.read_csv(url)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.fillna(df['Age'].mean(), inplace=True)
df.fillna(df['Embarked'].mode()[0], inplace=True)
df.drop(['Cabin','Ticket'], axis=1, inplace=True)

# %%
df.isnull().sum(), df.describe(),df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Fare         891 non-null    float64
#  9   Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 69.7+ KB
# (PassengerId    0
#  Survived       0
#  Pclass         0
#  Name           0
#  Sex            0
#  Age            0
#  SibSp          0
#  Parch          0
#  Fare           0
#  Embarked       0
#  dtype: int64,
#         PassengerId    Survived      Pclass         Age       SibSp  \
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
# df = pd.get_dummies(df, columns=['Sex'], drop_first=False)
# df[['Sex_female', 'Sex_male']] = df[['Sex_female', 'Sex_male']].astype(int)

df['Embarked'] = label_encoder.fit_transform(df['Embarked'])
df['Sex'] = label_encoder.fit_transform(df['Sex'])
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex        Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.000000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.000000      1
# 2                               Heikkinen, Miss. Laina    0  26.000000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.000000      1
# 4                             Allen, Mr. William Henry    1  35.000000      0
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex        Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.000000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.000000      1
# 2                               Heikkinen, Miss. Laina    0  26.000000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.000000      1
# 4                             Allen, Mr. William Henry    1  35.000000      0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Keep only numerical columns
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Calculate the correlation matrix
corr = numeric_df.corr()

# Create a heatmap
plt.figure(figsize=(10, 6))  # Optional: Adjust the figure size
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
df.groupby('Sex')['Survived'].mean().round(3)
# Out:
# Sex
# 0    0.742
# 1    0.189
# Name: Survived, dtype: float64

# %%
df_su=df['Survived'].value_counts(normalize=True)*100
df_su
# Out:
# Survived
# 0    61.616162
# 1    38.383838
# Name: proportion, dtype: float64

# %%
# Out:
# Survived
# 0    61.616162
# 1    38.383838
# Name: proportion, dtype: float64
